# %% [markdown]
# # **Atividade com Biblioteca Pandas**

# %% [markdown]
# ## Importe a biblioteca

# %%
#Importar Biblioteca
import pandas as pd
import statistics as st

# %% [markdown]
# ## Importe o dataframe

# %%
#Importar o dataframe
quali_vinho = pd.read_csv('qualidade_vinho.csv', sep=";")

# %% [markdown]
# ## Faça a visualização dos dados

# %%
#Visualizar dados
display(quali_vinho)
# Out:
#     acidez fixa acucar residual desidade    pH alcool qualidade
# 0           7,4             1,9   0,9978  3,51    9,4     baixa
# 1           7,8             2,6   0,9968   3,2    9,8     baixa
# 2           7,8             2,3    0,997  3,26    9,8     baixa
# 3          11,2             1,9    0,998  3,16    9,8     media
# 4           7,4             1,9   0,9978  3,51    9,4     baixa
# ..          ...             ...      ...   ...    ...       ...
# 295           9               3   0,9976  3,29     10     baixa
# 296         8,1             2,8   0,9994  3,43   11,1     media
# 297         6,4             1,8    0,997  3,46    9,5     baixa
# 298         6,4             1,8    0,997  3,46    9,5     baixa
# 299         6,4             3,2    0,995  3,61   12,7     media
#
# [300 rows x 6 columns]

# %% [markdown]
# ## Fazer uma análise geral

# %%
#Utilize o .info() .describe() .shape()
#Utilize o groupby() e size() nos valores qualitativos
#Verifique se há valores nulos
print(quali_vinho.shape)

print("-"*50)

display(quali_vinho.describe)

print("-"*50)

display(quali_vinho.info())
display(quali_vinho.isnull().sum())

print("-"*50)

display(quali_vinho.groupby('qualidade').size())
# Out:
# (300, 6)
# --------------------------------------------------
# <bound method NDFrame.describe of     acidez fixa acucar residual desidade    pH alcool qualidade
# 0           7,4             1,9   0,9978  3,51    9,4     baixa
# 1           7,8             2,6   0,9968   3,2    9,8     baixa
# 2           7,8             2,3    0,997  3,26    9,8     baixa
# 3          11,2             1,9    0,998  3,16    9,8     media
# 4           7,4             1,9   0,9978  3,51    9,4     baixa
# ..          ...             ...      ...   ...    ...       ...
# 295           9               3   0,9976  3,29     10     baixa
# 296         8,1             2,8   0,9994  3,43   11,1     media
# 297         6,4             1,8    0,997  3,46    9,5     baixa
# 298         6,4             1,8    0,997  3,46    9,5     baixa
# 299         6,4             3,2    0,995  3,61   12,7     media
#
# [300 rows x 6 columns]>
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   acidez fixa      300 non-null    object
#  1   acucar residual  299 non-null    object
#  2   desidade         299 non-null    object
#  3   pH               300 non-null    object
#  4   alcool           300 non-null    object
#  5   qualidade        300 non-null    object
# dtypes: object(6)
# memory usage: 14.2+ KB
# None
# acidez fixa        0
# acucar residual    1
# desidade           1
# pH                 0
# alcool             0
# qualidade          0
# dtype: int64
# --------------------------------------------------
# qualidade
# alta      44
# baixa    180
# media     76
# dtype: int64

# %% [markdown]
# ## Limpe os valores nulos e corrija os valores discrepantes ou errados

# %%
#Limpe os valores nulos e errados
display(quali_vinho.head())

moda_acucar = st.mode(quali_vinho["acucar residual"])
print(moda_acucar)

moda_densidade = st.mode(quali_vinho["desidade"])
print(moda_densidade)

quali_vinho.fillna({"acucar residual": moda_acucar}, inplace=True)
quali_vinho.fillna({"desidade": moda_densidade}, inplace=True)
# Out:
#   acidez fixa acucar residual desidade    pH alcool qualidade
# 0         7,4             1,9   0,9978  3,51    9,4     baixa
# 1         7,8             2,6   0,9968   3,2    9,8     baixa
# 2         7,8             2,3    0,997  3,26    9,8     baixa
# 3        11,2             1,9    0,998  3,16    9,8     media
# 4         7,4             1,9   0,9978  3,51    9,4     baixa
# 2
# 0,9968

# %% [markdown]
# ## Verifique se está tudo certo

# %%
#Verificando se os dados foram corrigidos
display(quali_vinho.isnull().sum())
# Out:
# acidez fixa        0
# acucar residual    0
# desidade           0
# pH                 0
# alcool             0
# qualidade          0
# dtype: int64
