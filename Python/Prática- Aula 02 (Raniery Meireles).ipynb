# %%
# imports das bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# lendo o dataset
df = pd.read_csv("alunos.csv")
df.head()
# Out:
#      nome sobrenome       sexo                    curso  semestre     ano  \
# 0   Carla   Pereira  Masculino  Arquitetura e Urbanismo       3.0  2024.0
# 1     NaN     Alves   Feminino  Arquitetura e Urbanismo       7.0  2025.0
# 2     NaN      Lima   Feminino               Enfermagem       NaN  2023.0
# 3    Igor       NaN   Feminino               Enfermagem       2.0  2024.0
# 4  Helena  Oliveira  Masculino  Arquitetura e Urbanismo       5.0  2024.0
#
#    nota1  nota2  nota3
# 0    8.6    NaN    8.8
# 1    6.2    9.8    9.6
# 2    8.5    9.7    9.8
# 3    8.2    NaN    6.8
# 4    NaN    5.2    5.2

# %% [markdown]
# # Análise geral do dataframe

# %%
# estrutura dos dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   nome       83 non-null     object
#  1   sobrenome  86 non-null     object
#  2   sexo       84 non-null     object
#  3   curso      89 non-null     object
#  4   semestre   81 non-null     float64
#  5   ano        87 non-null     float64
#  6   nota1      81 non-null     float64
#  7   nota2      88 non-null     float64
#  8   nota3      79 non-null     float64
# dtypes: float64(5), object(4)
# memory usage: 7.2+ KB

# %%
# número de linhas e colunas (dimensão)
df.shape
# Out:
# (100, 9)

# %%
# resumo com estatísticas descritivas
df.describe()
# Out:
#         semestre          ano      nota1      nota2      nota3
# count  81.000000    87.000000  81.000000  88.000000  79.000000
# mean    4.506173  2024.011494   7.337037   7.356818   7.483544
# std     2.308265     0.799626   1.524012   1.534192   1.401961
# min     1.000000  2023.000000   5.000000   5.000000   5.000000
# 25%     2.000000  2023.000000   6.000000   6.000000   6.500000
# 50%     5.000000  2024.000000   7.300000   7.300000   7.500000
# 75%     7.000000  2025.000000   8.700000   8.500000   8.500000
# max     8.000000  2025.000000  10.000000  10.000000  10.000000

# %%
# quartis
numeros = pd.Series([4, 5, 6, 7, 8, 9, 10])

# como calcular
q1 = numeros.quantile(0.25) #25%
print(q1)

#faça 50% e 75%
q2 = numeros.quantile(0.5) #50%
print(q2)

q3 = numeros.quantile(0.75) #75%
print(q3)

#printe na tela
numeros.describe()
# Out:
# 5.5
# 7.0
# 8.5
# count     7.000000
# mean      7.000000
# std       2.160247
# min       4.000000
# 25%       5.500000
# 50%       7.000000
# 75%       8.500000
# max      10.000000
# dtype: float64

# %%
# verificar dados nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   nome       83 non-null     object
#  1   sobrenome  86 non-null     object
#  2   sexo       84 non-null     object
#  3   curso      89 non-null     object
#  4   semestre   81 non-null     float64
#  5   ano        87 non-null     float64
#  6   nota1      81 non-null     float64
#  7   nota2      88 non-null     float64
#  8   nota3      79 non-null     float64
# dtypes: float64(5), object(4)
# memory usage: 7.2+ KB

# %% [markdown]
# # Numpy

# %%
[
  6.5, 7.0, 8.0, 9.5, 6.0, 7.5, 8.5, 9.0, 5.5, 6.0,
  7.0, 8.0, 9.0, 10.0, 6.5, 7.5, 8.5, 9.5, 6.0, 5.0,
  4.0, 5.5, 6.0, 7.0, 8.0, 9.0, 6.5, 7.5, 8.5, 9.5,
  6.0, 7.0, 8.0, 9.0, 10.0, 6.5, 5.0, 4.5, 5.5, 6.5,
  7.5, 8.0, 9.0, 6.0, 5.0, 4.5, 5.5, 6.5, 7.5, 8.5
]

# %%
notas_uniformes = np.random.uniform(low=0, high=10, size=50)
notas = np.round(notas_uniformes, 1)
notas
# Out:
# array([ 8.7,  6.1,  3.2,  3.6,  5.5,  3.4,  4.3,  9.2,  4. ,  4.1,  4.5,
#         0.7,  1.3,  3.5,  5. ,  0.9, 10. ,  0.7,  3.7,  4.1,  4.6,  6.1,
#         5.7,  0.9,  2.1,  3. ,  7. ,  6.3,  6. ,  6.3,  1.2,  2.3,  7.6,
#         8.1,  4.7,  1.8,  4.7,  2.8,  7.9,  4.9,  3.5,  7.2,  1.4,  3.7,
#         3.1,  1.3,  7.6,  7.3,  3.6,  6.3])

# %% [markdown]
# 1. Aplicarem uma operação vetorizada (ex: +1 em todas as notas)

# %%
print(notas + 1)
# Out:
# [ 9.7  7.1  4.2  4.6  6.5  4.4  5.3 10.2  5.   5.1  5.5  1.7  2.3  4.5
#   6.   1.9 11.   1.7  4.7  5.1  5.6  7.1  6.7  1.9  3.1  4.   8.   7.3
#   7.   7.3  2.2  3.3  8.6  9.1  5.7  2.8  5.7  3.8  8.9  5.9  4.5  8.2
#   2.4  4.7  4.1  2.3  8.6  8.3  4.6  7.3]

# %% [markdown]
# 2. Calcularem média, desvio padrão e nota mínima

# %%
media_notas = np.mean(notas)
dp_notas = np.std(notas)
min_notas = np.min(notas)

print(f"Média das notas {media_notas}\n Desvio padrão {dp_notas}\n Nota minima {min_notas}")
# Out:
# Média das notas 4.51
#  Desvio padrão 2.384554465723104
#  Nota minima 0.7

# %% [markdown]
# 3. Filtrarem as notas acima da média

# %%
print(notas[notas > media_notas])
# Out:
# [ 8.7  6.1  5.5  9.2  5.  10.   4.6  6.1  5.7  7.   6.3  6.   6.3  7.6
#   8.1  4.7  4.7  7.9  4.9  7.2  7.6  7.3  6.3]

# %% [markdown]
# # Matplotlib

# %% [markdown]
# 1. Utilizando um data set do drive,  faça:

# %% [markdown]
# Um gráfico de linha

# %%
df.columns
# Out:
# Index(['nome', 'sobrenome', 'sexo', 'curso', 'semestre', 'ano', 'nota1',
#        'nota2', 'nota3'],
#       dtype='object')

# %% [markdown]
# Um gráfico de barras

# %%
df[["nota1", "nota2", "nota2"]]
# Out:
#     nota1  nota2  nota2
# 0     8.6    NaN    NaN
# 1     6.2    9.8    9.8
# 2     8.5    9.7    9.7
# 3     8.2    NaN    NaN
# 4     NaN    5.2    5.2
# ..    ...    ...    ...
# 95    9.9    NaN    NaN
# 96    7.6    5.4    5.4
# 97    5.3    7.5    7.5
# 98    NaN    5.3    5.3
# 99    8.1    7.8    7.8
#
# [100 rows x 3 columns]

# %% [markdown]
# Um histograma

# %%
df["media"] = df[["nota1", "nota2", "nota3"]].mean(axis=1)
df
# Out:
#        nome sobrenome       sexo                    curso  semestre     ano  \
# 0     Carla   Pereira  Masculino  Arquitetura e Urbanismo       3.0  2024.0
# 1       NaN     Alves   Feminino  Arquitetura e Urbanismo       7.0  2025.0
# 2       NaN      Lima   Feminino               Enfermagem       NaN  2023.0
# 3      Igor       NaN   Feminino               Enfermagem       2.0  2024.0
# 4    Helena  Oliveira  Masculino  Arquitetura e Urbanismo       5.0  2024.0
# ..      ...       ...        ...                      ...       ...     ...
# 95    Carla   Pereira   Feminino   Engenharia de Software       NaN     NaN
# 96    Diego      Lima   Feminino                      NaN       6.0  2025.0
# 97      Ana       NaN   Feminino                      NaN       5.0  2024.0
# 98  Gustavo       NaN        NaN               Psicologia       2.0  2023.0
# 99  Gustavo     Costa   Feminino               Psicologia       7.0  2024.0
#
#     nota1  nota2  nota3     media
# 0     8.6    NaN    8.8  8.700000
# 1     6.2    9.8    9.6  8.533333
# 2     8.5    9.7    9.8  9.333333
# 3     8.2    NaN    6.8  7.500000
# 4     NaN    5.2    5.2  5.200000
# ..    ...    ...    ...       ...
# 95    9.9    NaN    NaN  9.900000
# 96    7.6    5.4    NaN  6.500000
# 97    5.3    7.5    6.3  6.366667
# 98    NaN    5.3    7.1  6.200000
# 99    8.1    7.8    6.6  7.500000
#
# [100 rows x 10 columns]

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(8,5))
plt.plot(df.index, df["media"], marker='o')
plt.title("Média das Notas po Aluno")
plt.xlabel("Aluno")
plt.ylabel("Média")
plt.show()

# %% [markdown]
# Obs: use as personalizações básicas apresentadas

# %% [markdown]
# # Searborn

# %% [markdown]
# 1. Utilizando um data set do drive,  faça:

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(data=df, x=df.index, y="media")
plt.title("Média das Notas por Aluno")
plt.xlabel("Aluno")
plt.ylabel("Média")
# Out:
# Text(0, 0.5, 'Média')

# %% [markdown]
# Um boxplot

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df[["nota1", "nota2", "nota3"]])
plt.title("Boxplot das Notas")
plt.ylabel("Notas")
plt.show()

# %% [markdown]
# Um histograma com kernel

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=df[["nota1", "nota2", "nota3"]], kde=True)
plt.title("Histograma com Kernel das Notas")
plt.ylabel("Frequência")
plt.show()

# %% [markdown]
# Um gráfico de dispersão

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x="nota1", y="nota2")
plt.title("Gráfico de Dispersão das Notas")
plt.xlabel("Nota 1")
plt.ylabel("Nota 2")
# Out:
# Text(0, 0.5, 'Nota 2')
